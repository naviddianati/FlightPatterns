# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import re
import statsmodels.formula.api as smf
# Out:
# /usr/local/lib/python2.7/dist-packages/scipy/__init__.py:111: UserWarning: Numpy 1.6.2 or above is recommended for this version of scipy (detected version 1.6.1)
#   UserWarning)

# %% [markdown]
# # Load the data

# %%
list_df = []
for counter in range(1,13):
    filename = '../data/{}-data.csv'.format(counter)
    list_df.append(pd.read_csv(filename))
data = pd.concat(list_df)
data = data.sort(['YEAR','MONTH','DAY_OF_MONTH','DEP_TIME'])
print 'Total number of reords:', len(data)
# Out:
# Total number of reords: 6096762

# %% [markdown]
# # Compile airport coordinate data

# %%
data_airports = pd.read_csv('../airports.csv', sep='|')

# Dictionary mapping each (city, state) tuple in airports file to
# its coordinates
dict_airports = {}



# DEPRECATED

print data_airports.columns
for i,row in data_airports.iterrows():
    try:
        city = row['city'].strip()
    except:
        continue
    state = row['state']
    dict_airports[(city, state)] = (row['lat'], row['long'])
# Out:
# Index([u'iata', u'airport', u'city', u'state', u'country', u'lat', u'long'], dtype='object')

# %%
def find_match(target_city, target_state):
    '''
    Attempt to find a match for the city given by target_city,
    target_state in dict_airports.
    @return (name, state) for the found match.
    '''
    target_city_split1 = target_city.split('/')
    target_city_split2 = target_city.split('-')
    
    for city in target_city_split1:
        if (city, target_state) in dict_airports:
            return (city, target_state)
    
    for city in target_city_split2:
        if (city, target_state) in dict_airports:
            return (city, target_state)
    
    city = re.sub('Fort', 'Ft\.', city)
    city = re.sub('St. ', 'St ',  city)

    if (city, target_state) in dict_airports:
            return (city, target_state)
    return None

# %% [markdown]
# ## Generate normalized city, lat, long dataframe

# %%
# List of cities appearing in the data
list_cities = list(data['ORIGIN_CITY_NAME'].unique())
print "Number of unique city names in database: ", len(list_cities)

# Maps each actual airport string (in list_cities) to a
# coordinate pair
dict_coordinates = {}

counter_error = 0
counter_matched = 0
for city in list_cities:
    name, state = city.split(',')
    state = state.strip()
    name = name.strip()
    try:
        dict_coordinates[city] = dict_airports[(name, state)]
    except:
        counter_error += 1
        match = find_match(name, state)
        if match:
            counter_matched += 1
            dict_coordinates[city] = dict_airports[match]

print len(list_cities), counter_error, counter_matched

data_coordinates = [(key, value[0], value[1]) for key, value in dict_coordinates.iteritems()]
data_coordinates = pd.DataFrame(data_coordinates, columns = ['city', 'lat', 'long'])
# Out:
# Number of unique city names in database:  307
# 307 45 33

# %% [markdown]
# ## Merge full data with coordinates table

# %%
data.columns
# Out:
# Index([u'YEAR', u'QUARTER', u'MONTH', u'DAY_OF_MONTH', u'DAY_OF_WEEK', u'FL_DATE', u'UNIQUE_CARRIER', u'AIRLINE_ID', u'CARRIER', u'ORIGIN_AIRPORT_ID', u'ORIGIN_AIRPORT_SEQ_ID', u'ORIGIN', u'ORIGIN_CITY_NAME', u'ORIGIN_STATE_ABR', u'DEST_AIRPORT_ID', u'DEST_AIRPORT_SEQ_ID', u'DEST_CITY_MARKET_ID', u'DEST', u'DEST_CITY_NAME', u'DEST_STATE_ABR', u'DEP_TIME', u'DEP_DELAY', u'ARR_TIME', u'ARR_DELAY', u'AIR_TIME', u'DISTANCE', u'Unnamed: 26'], dtype='object')

# %%
data_merged = pd.merge(data, data_coordinates, how='inner', left_on='ORIGIN_CITY_NAME', right_on='city' )
data_merged.rename(columns={'lat':'ORIGIN_LAT', 'long': 'ORIGIN_LONG'}, inplace=True)

# %%
data_merged = pd.merge(data_merged, data_coordinates, how='inner', left_on='DEST_CITY_NAME', right_on='city' )
data_merged.rename(columns = {'lat':'DEST_LAT', 'long': 'DEST_LONG'}, inplace=True)

# %%
n1,n2 = len(data_merged), len(data)
print n1,n2, (n2-n1)/float(n2)
# Out:
# 5866972 6096762 0.0376904986614

# %% [markdown]
# ## Add columns for LAT and LONG displacements

# %%
data_merged['D_LAT'] = data_merged['DEST_LAT'] - data_merged['ORIGIN_LAT']
data_merged['D_LONG'] = data_merged['DEST_LONG'] - data_merged['ORIGIN_LONG']
# data_merged[:10]

# %% [markdown]
# # Smaple the data

# %%
data_sample = data_merged.iloc[::60]
print len(data_sample)
# Out:
# 97783

# %% [markdown]
# # Exploration

# %% [markdown]
# ## Delay vs geographical location and time of year

# %%
df = data_sample[['ARR_DELAY', 'DEP_DELAY', 'D_LAT', 'D_LONG', 'DISTANCE', 'AIR_TIME']].dropna()
df = df[df['ARR_DELAY'] < 200]
# plt.plot(df['ARR_DELAY'],'.')

# %% [markdown]
# ## Standardize D_LAT and D_LONG

# %%
for column in ['D_LAT', 'D_LONG']:
    df[column] -= df[column].mean(); df[column] /= df[column].std()
df['DISTANCE'] /= df['DISTANCE'].std()

# %%
plt.hist(df['D_LONG'],20)
# Out:
# (array([   13,    15,    30,   128,  1046,  2066,  2404,  4244, 10546,
#         27446, 27400, 10572,  4250,  2406,  2061,  1052,   130,    33,
#            14,    12]),
#  array([ -5.37756886e+00,  -4.83984710e+00,  -4.30212535e+00,
#          -3.76440359e+00,  -3.22668184e+00,  -2.68896008e+00,
#          -2.15123832e+00,  -1.61351657e+00,  -1.07579481e+00,
#          -5.38073057e-01,  -3.51301086e-04,   5.37370455e-01,
#           1.07509221e+00,   1.61281397e+00,   2.15053572e+00,
#           2.68825748e+00,   3.22597923e+00,   3.76370099e+00,
#           4.30142275e+00,   4.83914450e+00,   5.37686626e+00]),
#  <a list of 20 Patch objects>)

# %%
data_sample.columns
# Out:
# Index([u'YEAR', u'QUARTER', u'MONTH', u'DAY_OF_MONTH', u'DAY_OF_WEEK', u'FL_DATE', u'UNIQUE_CARRIER', u'AIRLINE_ID', u'CARRIER', u'ORIGIN_AIRPORT_ID', u'ORIGIN_AIRPORT_SEQ_ID', u'ORIGIN', u'ORIGIN_CITY_NAME', u'ORIGIN_STATE_ABR', u'DEST_AIRPORT_ID', u'DEST_AIRPORT_SEQ_ID', u'DEST_CITY_MARKET_ID', u'DEST', u'DEST_CITY_NAME', u'DEST_STATE_ABR', u'DEP_TIME', u'DEP_DELAY', u'ARR_TIME', u'ARR_DELAY', u'AIR_TIME', u'DISTANCE', u'Unnamed: 26', u'city_x', u'ORIGIN_LAT', u'ORIGIN_LONG', u'city_y', u'DEST_LAT', u'DEST_LONG', u'D_LAT', u'D_LONG'], dtype='object')

# %%
# plt.hist(df['ORIGIN_LONG'], 20)

model = 'DEP_DELAY ~ ORIGIN_LAT + ORIGIN_LONG'
model = 'DEP_DELAY ~ ORIGIN_LAT + ORIGIN_LONG + ORIGIN_LAT:ORIGIN_LONG'
model = 'DEP_DELAY ~ ORIGIN_LAT:ORIGIN_LONG'
model = 'DEP_DELAY ~ MONTH + ORIGIN_LAT:ORIGIN_LONG'
model = 'DEP_DELAY ~ MONTH'
model = 'DEP_DELAY ~ MONTH + ORIGIN_LAT + ORIGIN_LONG + ORIGIN_LAT:ORIGIN_LONG'

model = 'ARR_DELAY ~ DISTANCE + D_LAT + D_LONG' # interesting

model = 'AIR_TIME ~ DISTANCE + D_LAT + D_LONG' #interesting
model = 'AIR_TIME ~ D_LAT + D_LONG'
model = 'AIR_TIME ~ D_LAT + D_LONG + D_LONG:D_LAT'
model = 'AIR_TIME ~ DISTANCE + D_LAT + D_LONG + D_LONG:D_LAT'
# model = 'AIR_TIME ~  D_LONG:D_LAT'

res = smf.ols(model, data = df).fit()
summary = res.summary()
print summary
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               AIR_TIME   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                 1.514e+06
# Date:                Tue, 08 Mar 2016   Prob (F-statistic):               0.00
# Time:                        22:36:58   Log-Likelihood:            -3.4376e+05
# No. Observations:               95868   AIC:                         6.875e+05
# Df Residuals:                   95863   BIC:                         6.876e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept       16.9986      0.047    363.365      0.000        16.907    17.090
# DISTANCE        69.0855      0.029   2359.173      0.000        69.028    69.143
# D_LAT            0.1938      0.028      6.812      0.000         0.138     0.250
# D_LONG          -7.1727      0.028   -252.150      0.000        -7.228    -7.117
# D_LONG:D_LAT    -0.1903      0.024     -7.861      0.000        -0.238    -0.143
# ==============================================================================
# Omnibus:                    21585.082   Durbin-Watson:                   1.319
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           120602.903
# Skew:                           0.972   Prob(JB):                         0.00
# Kurtosis:                       8.139   Cond. No.                         3.54
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
with open('table.tex', 'w') as f:
    f.write(summary.as_latex())

# %%
print "asd"
# Out:
# asd

# %% [markdown]
# ## Distribution of trajectory angles

# %%
angles = np.arctan(df['D_LONG'] / df['D_LAT'])
plt.hist(angles,20)
# Out:
# (array([2696, 4587, 4853, 4699, 3285, 4068, 3297, 6270, 6117, 5782, 4985,
#         7195, 4779, 7011, 4938, 5146, 2621, 4191, 5085, 4263]),
#  array([ -1.56967697e+00,  -1.41268143e+00,  -1.25568589e+00,
#          -1.09869034e+00,  -9.41694799e-01,  -7.84699255e-01,
#          -6.27703711e-01,  -4.70708167e-01,  -3.13712624e-01,
#          -1.56717080e-01,   2.78463982e-04,   1.57274008e-01,
#           3.14269552e-01,   4.71265095e-01,   6.28260639e-01,
#           7.85256183e-01,   9.42251727e-01,   1.09924727e+00,
#           1.25624281e+00,   1.41323836e+00,   1.57023390e+00]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ## Residuals

# %%
residuals = res.resid
print len(residuals), len(df)
plt.plot(df['DISTANCE'], residuals, '.k', alpha = 0.5)
# Out:
# 9616 9616

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
plt.hist(df['D_LAT'], 20)
plt.subplot(1,2,2)
plt.hist(df['D_LONG'], 20)
# Out:
# (array([   2,    2,    3,   11,  107,  207,  236,  412, 1055, 2712, 2807,
#         1049,  435,  239,  205,  115,   13,    4,    1,    1]),
#  array([-84.04979803, -75.6596208 , -67.26944356, -58.87926633,
#         -50.4890891 , -42.09891186, -33.70873463, -25.3185574 ,
#         -16.92838016,  -8.53820293,  -0.1480257 ,   8.24215154,
#          16.63232877,  25.02250601,  33.41268324,  41.80286047,
#          50.19303771,  58.58321494,  66.97339217,  75.36356941,  83.75374664]),
#  <a list of 20 Patch objects>)

# %%
plt.plot(data['DISTANCE'], data['DEP_DELAY'],'.', alpha = 0.05)

# %% [markdown]
# ## Arrival vs Departure delay

# %%
df = data_sample[['DEP_DELAY', 'ARR_DELAY']].dropna()
res = smf.ols('ARR_DELAY ~  DEP_DELAY ', data = df).fit()
print res.summary()
plt.plot(df['DEP_DELAY'], df['ARR_DELAY'], '.r', alpha = 0.2 )
plt.plot(df['DEP_DELAY'], res.fittedvalues,'-k', alpha = 1)
# plt.plot(data_sample['DEP_DELAY'], data_sample['DEP_DELAY'],'-k', alpha = 0.5)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              ARR_DELAY   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.881
# Method:                 Least Squares   F-statistic:                 7.443e+04
# Date:                Tue, 08 Mar 2016   Prob (F-statistic):               0.00
# Time:                        13:24:25   Log-Likelihood:                -39221.
# No. Observations:               10008   AIC:                         7.845e+04
# Df Residuals:                   10006   BIC:                         7.846e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -4.8121      0.125    -38.411      0.000        -5.058    -4.567
# DEP_DELAY      1.0071      0.004    272.813      0.000         1.000     1.014
# ==============================================================================
# Omnibus:                     3384.512   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            31729.481
# Skew:                           1.351   Prob(JB):                         0.00
# Kurtosis:                      11.294   Cond. No.                         34.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
residuals = res.resid.values
print residuals
plt.plot(df['DEP_DELAY'], residuals,'.k')
resid_fit = sm.OLS(residuals[1:], sm.add_constant(residuals[:-1])).fit()
# resid_fit = sm.OLS(residuals[1:], residuals[:-1]).fit()

# print(resid_fit.tvalues[1])
# print(resid_fit.pvalues[1])
# print resid_fit.summary()
print resid_fit.params
# Out:
# [  6.76955336   4.86176279 -21.17370237 ...,  -4.07439991  -8.30137696
#    0.85466976]
# [-0.00067328  0.03750979]

# %%
data.columns
# Out:
# Index([u'YEAR', u'MONTH', u'DAY_OF_MONTH', u'DAY_OF_WEEK', u'FL_DATE', u'UNIQUE_CARRIER', u'AIRLINE_ID', u'CARRIER', u'ORIGIN_AIRPORT_ID', u'ORIGIN_AIRPORT_SEQ_ID', u'ORIGIN', u'ORIGIN_CITY_NAME', u'ORIGIN_STATE_ABR', u'DEST_AIRPORT_ID', u'DEST_AIRPORT_SEQ_ID', u'DEST_CITY_MARKET_ID', u'DEST', u'DEST_STATE_ABR', u'DEP_TIME', u'DEP_DELAY', u'ARR_TIME', u'ARR_DELAY', u'AIR_TIME', u'DISTANCE', u'Unnamed: 24'], dtype='object')

# %% [markdown]
# ## Departure delay vs Departure time

# %%
plt.plot(data_sample['DEP_TIME'], data_sample['DEP_DELAY'], '.', alpha = 0.5)

# %% [markdown]
# ## Distance vs Departure time

# %%
plt.plot( data_sample['DEP_TIME'], data_sample['DISTANCE'], '.g', alpha = 0.5)
res = smf.ols('DEP_TIME ~ DISTANCE', data = data_sample).fit()
print res.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               DEP_TIME   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     8.385
# Date:                Tue, 08 Mar 2016   Prob (F-statistic):            0.00379
# Time:                        15:52:40   Log-Likelihood:                -76242.
# No. Observations:               10037   AIC:                         1.525e+05
# Df Residuals:                   10035   BIC:                         1.525e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1352.3001      7.935    170.423      0.000      1336.746  1367.854
# DISTANCE      -0.0234      0.008     -2.896      0.004        -0.039    -0.008
# ==============================================================================
# Omnibus:                     1953.423   Durbin-Watson:                   0.502
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              396.858
# Skew:                           0.048   Prob(JB):                     6.66e-87
# Kurtosis:                       2.031   Cond. No.                     1.62e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.62e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Tests and examples

# %% [markdown]
# ## Linear regression

# %%
n = 100
x = np.linspace(0,10,n)
df = pd.DataFrame(np.column_stack([x,np.zeros(n)]), columns=['x','y'])
df['y'] = 2 * df['x'] + np.random.normal(size = n)
plt.plot(df['x'], df['y'])

# %%
res = smf.ols('y ~ x', data = df).fit()
print res.summary()
plt.plot(df['x'], df['y'], '.')
plt.plot(df['x'], res.fittedvalues,'-r')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     4377.
# Date:                Tue, 08 Mar 2016   Prob (F-statistic):           3.91e-83
# Time:                        13:07:17   Log-Likelihood:                -127.10
# No. Observations:                 100   AIC:                             258.2
# Df Residuals:                      98   BIC:                             263.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.2474      0.173      1.430      0.156        -0.096     0.591
# x              1.9769      0.030     66.158      0.000         1.918     2.036
# ==============================================================================
# Omnibus:                        0.317   Durbin-Watson:                   1.782
# Prob(Omnibus):                  0.853   Jarque-Bera (JB):                0.135
# Skew:                          -0.087   Prob(JB):                        0.935
# Kurtosis:                       3.044   Cond. No.                         11.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
